# %% [markdown]
# # <font color='blue'>Data Science Academy - Python Fundamentos - Capítulo 6</font>
#
# ## Download: http://github.com/dsacademybr

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.6.5

# %% [markdown]
# ## Stream de Dados do Twitter com MongoDB, Pandas e Scikit Learn

# %% [markdown]
# ## Preparando a Conexão com o Twitter

# %%
# Instala o pacote tweepy
# !pip install tweepy
# Out:
# Requirement already satisfied: tweepy in c:\users\regia\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: PySocks>=1.5.7 in c:\users\regia\anaconda3\lib\site-packages (from tweepy) (1.6.8)
# Requirement already satisfied: requests>=2.11.1 in c:\users\regia\anaconda3\lib\site-packages (from tweepy) (2.18.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\regia\anaconda3\lib\site-packages (from tweepy) (1.3.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\regia\anaconda3\lib\site-packages (from tweepy) (1.11.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\regia\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in c:\users\regia\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\users\regia\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\regia\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (2019.11.28)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\regia\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.0)

# %%
# Importando os módulos Tweepy, Datetime e Json
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
from datetime import datetime
import json

# %% [markdown]
# Veja no manual em pdf como criar sua API no Twitter e configure as suas chaves abaixo.

# %%
# Adicione aqui sua Consumer Key
consumer_key = "PmIJILL1Doghf1IIbve6ZbH6B"

# %%
# Adicione aqui sua Consumer Secret 
consumer_secret = "XMLNS1B9CkRTXggBZSvNR6AnXPiZedhECISE4KMOyUgBfTS9gU"

# %%
# Adicione aqui seu Access Token
access_token = "115965475-1YzmIChewhoW0tdmB4qrzFqNYFRd0pD5Gi6XPvqO"

# %%
# Adicione aqui seu Access Token Secret
access_token_secret = "bCYkdNdbBYP0a87ezYwtPgE5Up7zfMbHzmpNiPGSk9aqg"

# %%
# Criando as chaves de autenticação
auth = OAuthHandler(consumer_key, consumer_secret)

# %%
auth.set_access_token(access_token, access_token_secret)

# %%
# Criando uma classe para capturar os stream de dados do Twitter e 
# armazenar no MongoDB
class MyListener(StreamListener):
    def on_data(self, dados):
        tweet = json.loads(dados)
        created_at = tweet["created_at"]
        id_str = tweet["id_str"]
        text = tweet["text"]
        obj = {"created_at":created_at,"id_str":id_str,"text":text,}
        tweetind = col.insert_one(obj).inserted_id
        print (obj)
        return True

# %%
# Criando o objeto mylistener
mylistener = MyListener()

# %%
# Criando o objeto mystream
mystream = Stream(auth, listener = mylistener)

# %% [markdown]
# ## Preparando a Conexão com o MongoDB

# %%
# Importando do PyMongo o módulo MongoClient
from pymongo import MongoClient

# %%
# Criando a conexão ao MongoDB
client = MongoClient('localhost', 27017)

# %%
# Criando o banco de dados twitterdb
db = client.twitterdb

# %%
# Criando a collection "col"
col = db.tweets

# %%
# Criando uma lista de palavras chave para buscar nos Tweets
keywords = ['Big Data', 'Python', 'Data Mining', 'Data Science']

# %% [markdown]
# ## Coletando os Tweets

# %%
# Iniciando o filtro e gravando os tweets no MongoDB
mystream.filter(track=keywords)
# Out:
# {'created_at': 'Sun May 31 21:19:32 +0000 2020', 'id_str': '1267204088938352640', 'text': 'RT @nostrabamus69: Curso básico/intermedio (y gratuito) de Python: \n\nhttps://t.co/tXnioS9pAO', '_id': ObjectId('5ed41f6ad4ae3f2d2780a016')}
# {'created_at': 'Sun May 31 21:19:33 +0000 2020', 'id_str': '1267204089689055234', 'text': 'RT @coupon05: Coupons Discount - HTML &amp; CSS Tutorial and Projects Course Courses -&gt; https://t.co/5IrvvCleH8\n\n#udemy #Free #webdevelopment #…', '_id': ObjectId('5ed41f6ad4ae3f2d2780a017')}
# {'created_at': 'Sun May 31 21:19:34 +0000 2020', 'id_str': '1267204094357356546', 'text': '@GinesRuizMacia @elEconomistaes Tela,...  El mismo Big Data que ha corregido los datos de fallecidos que no están f… https://t.co/hNMoEy1AH8', '_id': ObjectId('5ed41f6bd4ae3f2d2780a018')}
# {'created_at': 'Sun May 31 21:19:40 +0000 2020', 'id_str': '1267204120680816640', 'text': 'RT @Jx4nFrancisco: Programming in Laravel #reposted #programmerslife💻 #webdev #webdeveloper #webdevelopment #programming #programmer #progr…', '_id': ObjectId('5ed41f71d4ae3f2d2780a019')}
# {'created_at': 'Sun May 31 21:19:44 +0000 2020', 'id_str': '1267204136094904326', 'text': 'RT @Jx4nFrancisco: Programming in Laravel #reposted #programmerslife💻 #webdev #webdeveloper #webdevelopment #programming #programmer #progr…', '_id': ObjectId('5ed41f75d4ae3f2d2780a01a')}
# {'created_at': 'Sun May 31 21:19:45 +0000 2020', 'id_str': '1267204141052497923', 'text': 'RT @Jx4nFrancisco: Programming in Laravel #reposted #programmerslife💻 #webdev #webdeveloper #webdevelopment #programming #programmer #progr…', '_id': ObjectId('5ed41f76d4ae3f2d2780a01b')}
# {'created_at': 'Sun May 31 21:19:54 +0000 2020', 'id_str': '1267204179841429505', 'text': 'RT @jenbrea: WOW. @TheLancet did not give a shit about retracting the PACE trial. Nor has @guardian’s science editor given a shit about exp…', '_id': ObjectId('5ed41f7fd4ae3f2d2780a01c')}
# {'created_at': 'Sun May 31 21:20:03 +0000 2020', 'id_str': '1267204215211991041', 'text': 'Big data integration for transition from e-learning to smart learning framework. Dr. Prakash Kumar Udupi &amp; others… https://t.co/xdUUGsfi53', '_id': ObjectId('5ed41f88d4ae3f2d2780a01d')}
# {'created_at': 'Sun May 31 21:20:03 +0000 2020', 'id_str': '1267204216671604738', 'text': "@BHaarbrandt After more than 10 years in data 'Big Data' before it was labelled as such and roughly 12 years open s… https://t.co/7480n3YXcw", '_id': ObjectId('5ed41f88d4ae3f2d2780a01e')}
# {'created_at': 'Sun May 31 21:20:03 +0000 2020', 'id_str': '1267204218345021441', 'text': 'Studying smarter? How learning may change post-Covid lockdown: Now, bio has totally married data science—if you stu… https://t.co/Kyu852UsEl', '_id': ObjectId('5ed41f88d4ae3f2d2780a01f')}
# {'created_at': 'Sun May 31 21:20:04 +0000 2020', 'id_str': '1267204219137921028', 'text': 'RT @nayibbukele: A generic and cheap drug will not be as profitable as a new, patented one.\n\nIn the meantime, more the 300,000 deaths, and…', '_id': ObjectId('5ed41f89d4ae3f2d2780a020')}
# {'created_at': 'Sun May 31 21:20:04 +0000 2020', 'id_str': '1267204219708170240', 'text': 'Junior Consultant BI, Big Data, IoT https://t.co/XFHDFODhsf #bigdata #cdo #cto', '_id': ObjectId('5ed41f89d4ae3f2d2780a021')}
# {'created_at': 'Sun May 31 21:20:04 +0000 2020', 'id_str': '1267204220408586241', 'text': '@Dakarai_Turner I will provide accurate #data collection#, #data mining#, #data entry# and #web scraping#\nhttps://t.co/93OJ2LPCbJ', '_id': ObjectId('5ed41f89d4ae3f2d2780a022')}
# {'created_at': 'Sun May 31 21:20:04 +0000 2020', 'id_str': '1267204221029412866', 'text': 'Data Engineer: Implement scalable solutions to meet the ever-increasing data volumes, using big data/cloud technolo… https://t.co/oJVTVKriic', '_id': ObjectId('5ed41f89d4ae3f2d2780a023')}
# {'created_at': 'Sun May 31 21:20:04 +0000 2020', 'id_str': '1267204222019395587', 'text': 'RT @mattprescott: ... the handing over of NHS and public health DATA to big tech companies without strict data privacy requirements or limi…', '_id': ObjectId('5ed41f89d4ae3f2d2780a024')}
# {'created_at': 'Sun May 31 21:20:04 +0000 2020', 'id_str': '1267204222367363079', 'text': 'Five mines in Europe take part in €7-million digitization project: The project coordinator explained that this is n… https://t.co/5rNf7np8s9', '_id': ObjectId('5ed41f89d4ae3f2d2780a025')}
# {'created_at': 'Sun May 31 21:20:05 +0000 2020', 'id_str': '1267204223504015361', 'text': 'Mark Vaisberg Hirschhaut: It gave me a lot of confidence in a role that I was just starting. ... a talk, event, or… https://t.co/mFgQRXPZTN', '_id': ObjectId('5ed41f8ad4ae3f2d2780a026')}
# {'created_at': 'Sun May 31 21:20:05 +0000 2020', 'id_str': '1267204224770703361', 'text': 'COVID-19 Impact on Healthcare Analytics (Data Science) Market: Outlook, Growth, Key Driving ...: The medicine and h… https://t.co/yXFOZhGjFy', '_id': ObjectId('5ed41f8ad4ae3f2d2780a027')}
# {'created_at': 'Sun May 31 21:20:05 +0000 2020', 'id_str': '1267204225186041857', 'text': 'RT @realGuattari: PLEASE SHARE\n\nThis is a command line based tool that allows you to encrypt and decrypt files between you and your friends…', '_id': ObjectId('5ed41f8ad4ae3f2d2780a028')}
# {'created_at': 'Sun May 31 21:20:05 +0000 2020', 'id_str': '1267204225936707584', 'text': 'Big Data Engineer/Sr. Big Data Engineer: Big Data Engineer/Sr. Big Data Engineer. Newtown, Pennsylvania, United Sta… https://t.co/vhUE850U0S', '_id': ObjectId('5ed41f8ad4ae3f2d2780a029')}
# {'created_at': 'Sun May 31 21:20:05 +0000 2020', 'id_str': '1267204227056594944', 'text': 'Virtual Big Data Developer: A software development firm is seeking a Virtual Big Data Developer. Individual must be… https://t.co/9mzulUuf1T', '_id': ObjectId('5ed41f8bd4ae3f2d2780a02a')}
# {'created_at': 'Sun May 31 21:20:06 +0000 2020', 'id_str': '1267204228092551168', 'text': 'Big Data at the service of the intercultural in: Big Data at the service of the intercultural. in Management and ev… https://t.co/b8sXMGJ8dL', '_id': ObjectId('5ed41f8bd4ae3f2d2780a02b')}
# {'created_at': 'Sun May 31 21:20:07 +0000 2020', 'id_str': '1267204234988204034', 'text': 'RT @Jx4nFrancisco: Programming in Laravel #reposted #programmerslife💻 #webdev #webdeveloper #webdevelopment #programming #programmer #progr…', '_id': ObjectId('5ed41f8cd4ae3f2d2780a02c')}
# {'created_at': 'Sun May 31 21:20:10 +0000 2020', 'id_str': '1267204245406863360', 'text': 'RT @gp_pulipaka: A Curated List of #MachineLearning #Libraries, and #Books. #BigData #Analytics #DataScience #AI #IoT #IIoT #PyTorch #Pytho…', '_id': ObjectId('5ed41f8fd4ae3f2d2780a02d')}
# {'created_at': 'Sun May 31 21:20:12 +0000 2020', 'id_str': '1267204254604898307', 'text': 'python developer - https://t.co/6oH4BuoB22', '_id': ObjectId('5ed41f91d4ae3f2d2780a02e')}
# {'created_at': 'Sun May 31 21:20:14 +0000 2020', 'id_str': '1267204261697540101', 'text': 'RT @YossiGestetner: Days ago, the Lockdown Crowd was all righteous as to why the lockdowns need to continue and that force from PD can be d…', '_id': ObjectId('5ed41f93d4ae3f2d2780a02f')}
# {'created_at': 'Sun May 31 21:20:15 +0000 2020', 'id_str': '1267204269150744587', 'text': 'RT @rubie_shell: It is only a markup language.\n\n#Coding #Programming #Tech #Code #WebDeveloper #HTML #CSS  #Devops #NodeJS #VueJS #IoT  #Da…', '_id': ObjectId('5ed41f95d4ae3f2d2780a030')}
# {'created_at': 'Sun May 31 21:20:15 +0000 2020', 'id_str': '1267204269243076610', 'text': 'RT @OliverMensahDev: If you missed  #TheTechDemystify session with @saviour123, here is a link to the video: https://t.co/mR5xr4LQrs\n\n"Also…', '_id': ObjectId('5ed41f95d4ae3f2d2780a031')}
# {'created_at': 'Sun May 31 21:20:21 +0000 2020', 'id_str': '1267204292110422020', 'text': 'RT @DD_Wen_: Data Science Algorithms in a Week: Top 7 algorithms for scientific computing, data analysis, and machine learning, 2nd Edition…', '_id': ObjectId('5ed41f9ad4ae3f2d2780a032')}
# {'created_at': 'Sun May 31 21:20:21 +0000 2020', 'id_str': '1267204294010265600', 'text': 'I will provide accurate #data collection#, #data mining#, #data entry# and #web scraping#\nhttps://t.co/93OJ2LPCbJ', '_id': ObjectId('5ed41f9bd4ae3f2d2780a033')}
# {'created_at': 'Sun May 31 21:20:23 +0000 2020', 'id_str': '1267204301295890438', 'text': 'RT @realGuattari: PLEASE SHARE\n\nThis is a command line based tool that allows you to encrypt and decrypt files between you and your friends…', '_id': ObjectId('5ed41f9cd4ae3f2d2780a034')}
# {'created_at': 'Sun May 31 21:20:23 +0000 2020', 'id_str': '1267204301291687937', 'text': 'RT @LotusOak2: Please watch &amp; share #PlandemicDocumentary!\n&gt;&gt; https://t.co/4tMLit7271\n\nSubpoena Dr. Judy Mikovits @DrJudyAMikovits to testi…', '_id': ObjectId('5ed41f9cd4ae3f2d2780a035')}
# {'created_at': 'Sun May 31 21:20:25 +0000 2020', 'id_str': '1267204308606636032', 'text': 'RT @42Sz40: #programming #programmer #DevOps #webdevelopment #appdevelopment #100DaysOfCode #Java #Python #javascript #NodeJS #Angular #rea…', '_id': ObjectId('5ed41f9ed4ae3f2d2780a036')}
# {'created_at': 'Sun May 31 21:20:28 +0000 2020', 'id_str': '1267204323848736770', 'text': 'RT @KiteCri: #CETA #Mercosur #JETA #TAFTA #OTAN #Euroregion #GOPe #Art106destructionservicespublics #Frexit #Art50 #Europe #France #Indepen…', '_id': ObjectId('5ed41fa2d4ae3f2d2780a037')}
# {'created_at': 'Sun May 31 21:20:29 +0000 2020', 'id_str': '1267204326684008448', 'text': 'RT @mjcavaretta: I\'m a huge fan of #googletrends. A big hat tip to @Carrie_Fowle for the idea of using a "control term" to normalize across…', '_id': ObjectId('5ed41fa2d4ae3f2d2780a038')}
# {'created_at': 'Sun May 31 21:20:33 +0000 2020', 'id_str': '1267204341393510402', 'text': 'RT @YossiGestetner: Days ago, the Lockdown Crowd was all righteous as to why the lockdowns need to continue and that force from PD can be d…', '_id': ObjectId('5ed41fa6d4ae3f2d2780a039')}
# {'created_at': 'Sun May 31 21:20:37 +0000 2020', 'id_str': '1267204358254530560', 'text': 'Python required for Data Science and Machine Learning 2020 https://t.co/I6kjemuczW', '_id': ObjectId('5ed41faad4ae3f2d2780a03a')}
# {'created_at': 'Sun May 31 21:20:38 +0000 2020', 'id_str': '1267204361937137666', 'text': 'The lovely Chelsea Park Python is looking really looooooooong now #354 #paintarock #sheffieldissuper… https://t.co/g2yZDiVL5A', '_id': ObjectId('5ed41fabd4ae3f2d2780a03b')}
# {'created_at': 'Sun May 31 21:20:40 +0000 2020', 'id_str': '1267204370245890048', 'text': '@momogi_rn Semua gada yang mubazir mas, kuliah IT kan bukan melulu tentang koding, kita belajar juga macam-macam me… https://t.co/srCVfKjhSq', '_id': ObjectId('5ed41fadd4ae3f2d2780a03c')}
# {'created_at': 'Sun May 31 21:20:42 +0000 2020', 'id_str': '1267204380736008194', 'text': 'RT @rafi1227: Python required for Data Science and Machine Learning 2020 https://t.co/I6kjemuczW', '_id': ObjectId('5ed41fafd4ae3f2d2780a03d')}
# {'created_at': 'Sun May 31 21:20:43 +0000 2020', 'id_str': '1267204383097356288', 'text': 'RT @LotusOak2: Please watch &amp; share #PlandemicDocumentary!\n&gt;&gt; https://t.co/4tMLit7271\n\nSubpoena Dr. Judy Mikovits @DrJudyAMikovits to testi…', '_id': ObjectId('5ed41fb0d4ae3f2d2780a03e')}
# {'created_at': 'Sun May 31 21:20:44 +0000 2020', 'id_str': '1267204387035889664', 'text': 'RT @Jx4nFrancisco: Programming in Laravel #reposted #programmerslife💻 #webdev #webdeveloper #webdevelopment #programming #programmer #progr…', '_id': ObjectId('5ed41fb1d4ae3f2d2780a03f')}
# {'created_at': 'Sun May 31 21:20:44 +0000 2020', 'id_str': '1267204388197556224', 'text': 'RT @YossiGestetner: Days ago, the Lockdown Crowd was all righteous as to why the lockdowns need to continue and that force from PD can be d…', '_id': ObjectId('5ed41fb1d4ae3f2d2780a040')}
# {'created_at': 'Sun May 31 21:20:47 +0000 2020', 'id_str': '1267204399979540481', 'text': 'Isso aí é uma interface online onde você vai poder fazer o teste com a sua foto!! \n\nSoltaremos essa semana!!', '_id': ObjectId('5ed41fb4d4ae3f2d2780a041')}
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1613         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1614             raise WantReadError()
#    1615         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-6a9070444200> in <module>()
#       1 # Iniciando o filtro e gravando os tweets no MongoDB
# ----> 2 mystream.filter(track=keywords)
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~\Anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     382             else:
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     386                     # Close the connection when no data is returned
#
# ~\Anaconda3\lib\http\client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# ~\Anaconda3\lib\http\client.py in readinto(self, b)
#     481
#     482         if self.chunked:
# --> 483             return self._readinto_chunked(b)
#     484
#     485         if self.length is not None:
#
# ~\Anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     576         try:
#     577             while True:
# --> 578                 chunk_left = self._get_chunk_left()
#     579                 if chunk_left is None:
#     580                     return total_bytes
#
# ~\Anaconda3\lib\http\client.py in _get_chunk_left(self)
#     544                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     545             try:
# --> 546                 chunk_left = self._read_next_chunk_size()
#     547             except ValueError:
#     548                 raise IncompleteRead(b'')
#
# ~\Anaconda3\lib\http\client.py in _read_next_chunk_size(self)
#     504     def _read_next_chunk_size(self):
#     505         # Read the next chunk size from the file
# --> 506         line = self.fp.readline(_MAXLINE + 1)
#     507         if len(line) > _MAXLINE:
#     508             raise LineTooLong("chunk size")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     290                 raise
#     291         except OpenSSL.SSL.WantReadError:
# --> 292             rd = util.wait_for_read(self.socket, self.socket.gettimeout())
#     293             if not rd:
#     294                 raise timeout('The read operation timed out')
#
# ~\Anaconda3\lib\site-packages\urllib3\util\wait.py in wait_for_read(socks, timeout)
#      31     or optionally a single socket if passed in. Returns a list of
#      32     sockets that can be read from immediately. """
# ---> 33     return _wait_for_io_events(socks, EVENT_READ, timeout)
#      34
#      35
#
# ~\Anaconda3\lib\site-packages\urllib3\util\wait.py in _wait_for_io_events(socks, events, timeout)
#      24             selector.register(sock, events)
#      25         return [key[0].fileobj for key in
# ---> 26                 selector.select(timeout) if key[1] & events]
#      27
#      28
#
# ~\Anaconda3\lib\site-packages\urllib3\util\selectors.py in select(self, timeout)
#     318             ready = []
#     319             r, w, _ = _syscall_wrapper(self._select, True, self._readers,
# --> 320                                        self._writers, timeout)
#     321             r = set(r)
#     322             w = set(w)
#
# ~\Anaconda3\lib\site-packages\urllib3\util\selectors.py in _syscall_wrapper(func, _, *args, **kwargs)
#      62         and recalculate their timeouts. """
#      63         try:
# ---> 64             return func(*args, **kwargs)
#      65         except (OSError, IOError, select.error) as e:
#      66             errcode = None
#
# ~\Anaconda3\lib\site-packages\urllib3\util\selectors.py in _select(self, r, w, timeout)
#     308         def _select(self, r, w, timeout=None):
#     309             """ Wrapper for select.select because timeout is a positional arg """
# --> 310             return select.select(r, w, [], timeout)
#     311
#     312         def select(self, timeout=None):
#
# KeyboardInterrupt:

# %% [markdown]
# ## --> Pressione o botão Stop na barra de ferramentas para encerrar a captura dos Tweets

# %% [markdown]
# ## Consultando os Dados no MongoDB

# %%
mystream.disconnect()

# %%
# Verificando um documento no collection
col.find_one()
# Out:
# {'_id': ObjectId('5ed41f6ad4ae3f2d2780a016'),
#  'created_at': 'Sun May 31 21:19:32 +0000 2020',
#  'id_str': '1267204088938352640',
#  'text': 'RT @nostrabamus69: Curso básico/intermedio (y gratuito) de Python: \n\nhttps://t.co/tXnioS9pAO'}

# %% [markdown]
# ## Análise de Dados com Pandas e Scikit-Learn

# %%
# criando um dataset com dados retornados do MongoDB
dataset = [{"created_at": item["created_at"], "text": item["text"],} for item in col.find()]

# %%
# Importando o módulo Pandas para trabalhar com datasets em Python
import pandas as pd
pd.__version__
# Out:
# '0.23.0'

# %%
# Criando um dataframe a partir do dataset 
df = pd.DataFrame(dataset)

# %%
# Imprimindo o dataframe
df
# Out:
#                         created_at  \
# 0   Sun May 31 21:19:32 +0000 2020
# 1   Sun May 31 21:19:33 +0000 2020
# 2   Sun May 31 21:19:34 +0000 2020
# 3   Sun May 31 21:19:40 +0000 2020
# 4   Sun May 31 21:19:44 +0000 2020
# 5   Sun May 31 21:19:45 +0000 2020
# 6   Sun May 31 21:19:54 +0000 2020
# 7   Sun May 31 21:20:03 +0000 2020
# 8   Sun May 31 21:20:03 +0000 2020
# 9   Sun May 31 21:20:03 +0000 2020
# 10  Sun May 31 21:20:04 +0000 2020
# 11  Sun May 31 21:20:04 +0000 2020
# 12  Sun May 31 21:20:04 +0000 2020
# 13  Sun May 31 21:20:04 +0000 2020
# 14  Sun May 31 21:20:04 +0000 2020
# 15  Sun May 31 21:20:04 +0000 2020
# 16  Sun May 31 21:20:05 +0000 2020
# 17  Sun May 31 21:20:05 +0000 2020
# 18  Sun May 31 21:20:05 +0000 2020
# 19  Sun May 31 21:20:05 +0000 2020
# 20  Sun May 31 21:20:05 +0000 2020
# 21  Sun May 31 21:20:06 +0000 2020
# 22  Sun May 31 21:20:07 +0000 2020
# 23  Sun May 31 21:20:10 +0000 2020
# 24  Sun May 31 21:20:12 +0000 2020
# 25  Sun May 31 21:20:14 +0000 2020
# 26  Sun May 31 21:20:15 +0000 2020
# 27  Sun May 31 21:20:15 +0000 2020
# 28  Sun May 31 21:20:21 +0000 2020
# 29  Sun May 31 21:20:21 +0000 2020
# 30  Sun May 31 21:20:23 +0000 2020
# 31  Sun May 31 21:20:23 +0000 2020
# 32  Sun May 31 21:20:25 +0000 2020
# 33  Sun May 31 21:20:28 +0000 2020
# 34  Sun May 31 21:20:29 +0000 2020
# 35  Sun May 31 21:20:33 +0000 2020
# 36  Sun May 31 21:20:37 +0000 2020
# 37  Sun May 31 21:20:38 +0000 2020
# 38  Sun May 31 21:20:40 +0000 2020
# 39  Sun May 31 21:20:42 +0000 2020
# 40  Sun May 31 21:20:43 +0000 2020
# 41  Sun May 31 21:20:44 +0000 2020
# 42  Sun May 31 21:20:44 +0000 2020
# 43  Sun May 31 21:20:47 +0000 2020
#
#                                                  text
# 0   RT @nostrabamus69: Curso básico/intermedio (y ...
# 1   RT @coupon05: Coupons Discount - HTML &amp; CS...
# 2   @GinesRuizMacia @elEconomistaes Tela,...  El m...
# 3   RT @Jx4nFrancisco: Programming in Laravel #rep...
# 4   RT @Jx4nFrancisco: Programming in Laravel #rep...
# 5   RT @Jx4nFrancisco: Programming in Laravel #rep...
# 6   RT @jenbrea: WOW. @TheLancet did not give a sh...
# 7   Big data integration for transition from e-lea...
# 8   @BHaarbrandt After more than 10 years in data ...
# 9   Studying smarter? How learning may change post...
# 10  RT @nayibbukele: A generic and cheap drug will...
# 11  Junior Consultant BI, Big Data, IoT https://t....
# 12  @Dakarai_Turner I will provide accurate #data ...
# 13  Data Engineer: Implement scalable solutions to...
# 14  RT @mattprescott: ... the handing over of NHS ...
# 15  Five mines in Europe take part in €7-million d...
# 16  Mark Vaisberg Hirschhaut: It gave me a lot of ...
# 17  COVID-19 Impact on Healthcare Analytics (Data ...
# 18  RT @realGuattari: PLEASE SHARE\n\nThis is a co...
# 19  Big Data Engineer/Sr. Big Data Engineer: Big D...
# 20  Virtual Big Data Developer: A software develop...
# 21  Big Data at the service of the intercultural i...
# 22  RT @Jx4nFrancisco: Programming in Laravel #rep...
# 23  RT @gp_pulipaka: A Curated List of #MachineLea...
# 24         python developer - https://t.co/6oH4BuoB22
# 25  RT @YossiGestetner: Days ago, the Lockdown Cro...
# 26  RT @rubie_shell: It is only a markup language....
# 27  RT @OliverMensahDev: If you missed  #TheTechDe...
# 28  RT @DD_Wen_: Data Science Algorithms in a Week...
# 29  I will provide accurate #data collection#, #da...
# 30  RT @realGuattari: PLEASE SHARE\n\nThis is a co...
# 31  RT @LotusOak2: Please watch &amp; share #Pland...
# 32  RT @42Sz40: #programming #programmer #DevOps #...
# 33  RT @KiteCri: #CETA #Mercosur #JETA #TAFTA #OTA...
# 34  RT @mjcavaretta: I'm a huge fan of #googletren...
# 35  RT @YossiGestetner: Days ago, the Lockdown Cro...
# 36  Python required for Data Science and Machine L...
# 37  The lovely Chelsea Park Python is looking real...
# 38  @momogi_rn Semua gada yang mubazir mas, kuliah...
# 39  RT @rafi1227: Python required for Data Science...
# 40  RT @LotusOak2: Please watch &amp; share #Pland...
# 41  RT @Jx4nFrancisco: Programming in Laravel #rep...
# 42  RT @YossiGestetner: Days ago, the Lockdown Cro...
# 43  Isso aí é uma interface online onde você vai p...

# %%
# Importando o módulo Scikit Learn
from sklearn.feature_extraction.text import CountVectorizer

# %%
import sklearn
sklearn.__version__
# Out:
# '0.19.1'

# %%
# Usando o método CountVectorizer para criar uma matriz de documentos
cv = CountVectorizer()
count_matrix = cv.fit_transform(df.text)

# %%
# Contando o número de ocorrências das principais palavras em nosso dataset
word_count = pd.DataFrame(cv.get_feature_names(), columns=["word"])
word_count["count"] = count_matrix.sum(axis=0).tolist()[0]
word_count = word_count.sort_values("count", ascending=False).reset_index(drop=True)
word_count[:50]
# Out:
#                word  count
# 0              data     30
# 1                rt     25
# 2             https     24
# 3                co     24
# 4               and     20
# 5               the     20
# 6                to     16
# 7               big     15
# 8                in     13
# 9       programming     12
# 10               of      7
# 11             that      7
# 12   webdevelopment      7
# 13               is      7
# 14     webdeveloper      6
# 15       programmer      6
# 16         learning      6
# 17          science      6
# 18           python      6
# 19              you      6
# 20               as      6
# 21         reposted      5
# 22            progr      5
# 23              for      5
# 24          laravel      5
# 25           webdev      5
# 26    jx4nfrancisco      5
# 27         engineer      5
# 28  programmerslife      5
# 29               be      5
# 30              was      5
# 31               gt      5
# 32             from      4
# 33           please      4
# 34            share      4
# 35               it      4
# 36         lockdown      4
# 37              amp      4
# 38         continue      3
# 39        lockdowns      3
# 40              iot      3
# 41        righteous      3
# 42             this      3
# 43             need      3
# 44          machine      3
# 45              can      3
# 46            force      3
# 47            crowd      3
# 48   yossigestetner      3
# 49               dr      3

# %% [markdown]
# # Fim

# %% [markdown]
# ### Obrigado - Data Science Academy - <a href="http://facebook.com/dsacademybr">facebook.com/dsacademybr</a>
